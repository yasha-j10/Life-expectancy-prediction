# %% [markdown]
# <a href="https://colab.research.google.com/github/yasha-j10/Life-expectancy-prediction/blob/main/Project_LifeExpectancyPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer
from sklearn.model_selection import KFold
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn import metrics

# %%
#loading the data
url = ('https://raw.githubusercontent.com/nehagianchandani/Life_Expectancy/master/Life%20Expectancy%20Data.csv')
life_data = pd.read_csv(url)

# %%
life_data
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0                62     0.01               71.279624         65.0      1154
# 1                64     0.01               73.523582         62.0       492
# 2                66     0.01               73.219243         64.0       430
# 3                69     0.01               78.184215         67.0      2787
# 4                71     0.01                7.097109         68.0      3013
# ...             ...      ...                     ...          ...       ...
# 2933             27     4.36                0.000000         68.0        31
# 2934             26     4.06                0.000000          7.0       998
# 2935             25     4.43                0.000000         73.0       304
# 2936             25     1.72                0.000000         76.0       529
# 2937             24     1.68                0.000000         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 0     ...    6.0               8.16         65.0        0.1  584.259210
# 1     ...   58.0               8.18         62.0        0.1  612.696514
# 2     ...   62.0               8.13         64.0        0.1  631.744976
# 3     ...   67.0               8.52         67.0        0.1  669.959000
# 4     ...   68.0               7.87         68.0        0.1   63.537231
# ...   ...    ...                ...          ...        ...         ...
# 2933  ...   67.0               7.13         65.0       33.6  454.366654
# 2934  ...    7.0               6.52         68.0       36.7  453.351155
# 2935  ...   73.0               6.53         71.0       39.8   57.348340
# 2936  ...   76.0               6.16         75.0       42.1  548.587312
# 2937  ...   78.0               7.10         78.0       43.5  547.358878
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 0     33736494.0                   17.2                 17.3
# 1       327582.0                   17.5                 17.5
# 2     31731688.0                   17.7                 17.7
# 3      3696958.0                   17.9                 18.0
# 4      2978599.0                   18.2                 18.2
# ...          ...                    ...                  ...
# 2933  12777511.0                    9.4                  9.4
# 2934  12633897.0                    9.8                  9.9
# 2935    125525.0                    1.2                  1.3
# 2936  12366165.0                    1.6                  1.7
# 2937  12222251.0                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2938 rows x 22 columns]

# %%
life_data = life_data.drop('Year', axis = 1)

# %%
life_data.head()
# Out:
#        Country      Status  Life expectancy   Adult Mortality  infant deaths  \
# 0  Afghanistan  Developing              65.0            263.0             62
# 1  Afghanistan  Developing              59.9            271.0             64
# 2  Afghanistan  Developing              59.9            268.0             66
# 3  Afghanistan  Developing              59.5            272.0             69
# 4  Afghanistan  Developing              59.2            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   ...  Polio  \
# 0     0.01               71.279624         65.0      1154   19.1  ...    6.0
# 1     0.01               73.523582         62.0       492   18.6  ...   58.0
# 2     0.01               73.219243         64.0       430   18.1  ...   62.0
# 3     0.01               78.184215         67.0      2787   17.6  ...   67.0
# 4     0.01                7.097109         68.0      3013   17.2  ...   68.0
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0               8.16         65.0        0.1  584.259210  33736494.0
# 1               8.18         62.0        0.1  612.696514    327582.0
# 2               8.13         64.0        0.1  631.744976  31731688.0
# 3               8.52         67.0        0.1  669.959000   3696958.0
# 4               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 21 columns]

# %%
status = pd.get_dummies(life_data.Status)

# %%
life_data = pd.concat([life_data, status], axis = 1)

# %%
life_data = life_data.drop(['Status'], axis=1)

# %%
life_data.rename(columns = {'Developing' : '0', 'Developed' : 1})
# Out:
#           Country  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0     Afghanistan              65.0            263.0             62     0.01
# 1     Afghanistan              59.9            271.0             64     0.01
# 2     Afghanistan              59.9            268.0             66     0.01
# 3     Afghanistan              59.5            272.0             69     0.01
# 4     Afghanistan              59.2            275.0             71     0.01
# ...           ...               ...              ...            ...      ...
# 2933     Zimbabwe              44.3            723.0             27     4.36
# 2934     Zimbabwe              44.5            715.0             26     4.06
# 2935     Zimbabwe              44.8             73.0             25     4.43
# 2936     Zimbabwe              45.3            686.0             25     1.72
# 2937     Zimbabwe              46.0            665.0             24     1.68
#
#       percentage expenditure  Hepatitis B  Measles    BMI   \
# 0                  71.279624         65.0      1154   19.1
# 1                  73.523582         62.0       492   18.6
# 2                  73.219243         64.0       430   18.1
# 3                  78.184215         67.0      2787   17.6
# 4                   7.097109         68.0      3013   17.2
# ...                      ...          ...       ...    ...
# 2933                0.000000         68.0        31   27.1
# 2934                0.000000          7.0       998   26.7
# 2935                0.000000         73.0       304   26.3
# 2936                0.000000         76.0       529   25.9
# 2937                0.000000         79.0      1483   25.5
#
#       under-five deaths   ...  Diphtheria    HIV/AIDS         GDP  Population  \
# 0                     83  ...         65.0        0.1  584.259210  33736494.0
# 1                     86  ...         62.0        0.1  612.696514    327582.0
# 2                     89  ...         64.0        0.1  631.744976  31731688.0
# 3                     93  ...         67.0        0.1  669.959000   3696958.0
# 4                     97  ...         68.0        0.1   63.537231   2978599.0
# ...                  ...  ...          ...        ...         ...         ...
# 2933                  42  ...         65.0       33.6  454.366654  12777511.0
# 2934                  41  ...         68.0       36.7  453.351155  12633897.0
# 2935                  40  ...         71.0       39.8   57.348340    125525.0
# 2936                  39  ...         75.0       42.1  548.587312  12366165.0
# 2937                  39  ...         78.0       43.5  547.358878  12222251.0
#
#        thinness  1-19 years   thinness 5-9 years  \
# 0                      17.2                 17.3
# 1                      17.5                 17.5
# 2                      17.7                 17.7
# 3                      17.9                 18.0
# 4                      18.2                 18.2
# ...                     ...                  ...
# 2933                    9.4                  9.4
# 2934                    9.8                  9.9
# 2935                    1.2                  1.3
# 2936                    1.6                  1.7
# 2937                   11.0                 11.2
#
#       Income composition of resources  Schooling  1  0
# 0                               0.479       10.1  0  1
# 1                               0.476       10.0  0  1
# 2                               0.470        9.9  0  1
# 3                               0.463        9.8  0  1
# 4                               0.454        9.5  0  1
# ...                               ...        ... .. ..
# 2933                            0.407        9.2  0  1
# 2934                            0.418        9.5  0  1
# 2935                            0.427       10.0  0  1
# 2936                            0.427        9.8  0  1
# 2937                            0.434        9.8  0  1
#
# [2938 rows x 22 columns]

# %%
life_data = life_data.groupby('Country').mean()

# %%
life_data.head()
# Out:
#                      Life expectancy   Adult Mortality  infant deaths  \
# Country
# Afghanistan                  58.19375         269.0625        78.2500
# Albania                      75.15625          45.0625         0.6875
# Algeria                      73.61875         108.1875        20.3125
# Angola                       49.01875         328.5625        83.7500
# Antigua and Barbuda          75.05625         127.5000         0.0000
#
#                       Alcohol  percentage expenditure  Hepatitis B   Measles   \
# Country
# Afghanistan          0.014375               34.960110    64.562500  2362.2500
# Albania              4.848750              193.259091    98.000000    53.3750
# Algeria              0.406667              236.185241    78.000000  1943.8750
# Angola               5.740667              102.100268    70.222222  3561.3125
# Antigua and Barbuda  7.949333             1001.585226    98.266667     0.0000
#
#                          BMI   under-five deaths     Polio  ...  Diphtheria   \
# Country                                                     ...
# Afghanistan          15.51875            107.5625  48.3750  ...      52.3125
# Albania              49.06875              0.9375  98.1250  ...      98.0625
# Algeria              48.74375             23.5000  91.7500  ...      91.8750
# Angola               18.01875            132.6250  46.1250  ...      47.6875
# Antigua and Barbuda  38.42500              0.0000  96.9375  ...      98.3125
#
#                       HIV/AIDS          GDP    Population  \
# Country
# Afghanistan            0.10000   340.015425  9.972260e+06
# Albania                0.10000  2119.726679  6.969116e+05
# Algeria                0.10000  2847.853392  2.164983e+07
# Angola                 2.36875  1975.143045  1.014710e+07
# Antigua and Barbuda    0.12500  9759.305728           NaN
#
#                       thinness  1-19 years   thinness 5-9 years  \
# Country
# Afghanistan                       16.58125             15.58125
# Albania                            1.61875              1.70000
# Algeria                            6.09375              5.97500
# Angola                             6.19375              6.66875
# Antigua and Barbuda                3.42500              3.37500
#
#                      Income composition of resources  Schooling  Developed  \
# Country
# Afghanistan                                 0.415375    8.21250        0.0
# Albania                                     0.709875   12.13750        0.0
# Algeria                                     0.694875   12.71250        0.0
# Angola                                      0.458375    8.04375        0.0
# Antigua and Barbuda                         0.488625    8.84375        0.0
#
#                      Developing
# Country
# Afghanistan                 1.0
# Albania                     1.0
# Algeria                     1.0
# Angola                      1.0
# Antigua and Barbuda         1.0
#
# [5 rows x 21 columns]

# %%
life_data.columns
# Out:
# Index(['Life expectancy ', 'Adult Mortality', 'infant deaths', 'Alcohol',
#        'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
#        'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
#        ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
#        ' thinness 5-9 years', 'Income composition of resources', 'Schooling',
#        'Developed', 'Developing'],
#       dtype='object')

# %%
life_data.hist(bins = 30, figsize = (20, 20), color = 'purple');

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
plt.scatter(life_data[' HIV/AIDS'], life_data['Life expectancy '],color='purple')
plt.xlabel('HIV/AIDS')
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(life_data.GDP, life_data['Life expectancy '],color='purple')
plt.xlabel('GDP')
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(life_data[' BMI '], life_data['Life expectancy '],color='purple')
plt.xlabel('BMI')
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(life_data['under-five deaths '], life_data['Life expectancy '],color='purple')
plt.xlabel('under-five deaths')
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(life_data['Alcohol'], life_data['Life expectancy '],color='purple')
plt.xlabel('Alcohol')
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(life_data['Adult Mortality'], life_data['Life expectancy '],color='purple')
plt.xlabel('Adult Mortality')
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(life_data['Schooling'], life_data['Life expectancy '],color='purple')
plt.xlabel('Schooling')
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
plt.scatter(life_data['percentage expenditure'], life_data['Life expectancy '],color='purple')
plt.xlabel('Percentage Healhcare expenditure')
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
life_labels = life_data['Life expectancy ']
life_features = life_data.drop('Life expectancy ', axis = 1)
X=life_features

# %% [markdown]
# DATA-PREPROCESSING

# %%
sns.heatmap(life_data.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
life_features.isnull().head()
# Out:
#                      Adult Mortality  infant deaths  Alcohol  \
# Country
# Afghanistan                    False          False    False
# Albania                        False          False    False
# Algeria                        False          False    False
# Angola                         False          False    False
# Antigua and Barbuda            False          False    False
#
#                      percentage expenditure  Hepatitis B  Measles    BMI   \
# Country
# Afghanistan                           False        False     False  False
# Albania                               False        False     False  False
# Algeria                               False        False     False  False
# Angola                                False        False     False  False
# Antigua and Barbuda                   False        False     False  False
#
#                      under-five deaths   Polio  Total expenditure  \
# Country
# Afghanistan                       False  False              False
# Albania                           False  False              False
# Algeria                           False  False              False
# Angola                            False  False              False
# Antigua and Barbuda               False  False              False
#
#                      Diphtheria    HIV/AIDS    GDP  Population  \
# Country
# Afghanistan                False      False  False       False
# Albania                    False      False  False       False
# Algeria                    False      False  False       False
# Angola                     False      False  False       False
# Antigua and Barbuda        False      False  False        True
#
#                       thinness  1-19 years   thinness 5-9 years  \
# Country
# Afghanistan                          False                False
# Albania                              False                False
# Algeria                              False                False
# Angola                               False                False
# Antigua and Barbuda                  False                False
#
#                      Income composition of resources  Schooling  Developed  \
# Country
# Afghanistan                                    False      False      False
# Albania                                        False      False      False
# Algeria                                        False      False      False
# Angola                                         False      False      False
# Antigua and Barbuda                            False      False      False
#
#                      Developing
# Country
# Afghanistan               False
# Albania                   False
# Algeria                   False
# Angola                    False
# Antigua and Barbuda       False

# %%
life_features.isnull().sum()
# Out:
# Adult Mortality                    10
# infant deaths                       0
# Alcohol                             2
# percentage expenditure              0
# Hepatitis B                         9
# Measles                             0
#  BMI                                4
# under-five deaths                   0
# Polio                               0
# Total expenditure                   2
# Diphtheria                          0
#  HIV/AIDS                           0
# GDP                                30
# Population                         48
#  thinness  1-19 years               4
#  thinness 5-9 years                 4
# Income composition of resources    17
# Schooling                          13
# Developed                           0
# Developing                          0
# dtype: int64

# %%
life_labels.isnull().sum()
# Out:
# 10

# %%
life_features.fillna(value = life_features.mean(), inplace = True)
life_features
# Out:
#                                     Adult Mortality  infant deaths   Alcohol  \
# Country
# Afghanistan                                269.0625        78.2500  0.014375
# Albania                                     45.0625         0.6875  4.848750
# Algeria                                    108.1875        20.3125  0.406667
# Angola                                     328.5625        83.7500  5.740667
# Antigua and Barbuda                        127.5000         0.0000  7.949333
# ...                                             ...            ...       ...
# Venezuela (Bolivarian Republic of)         163.0000         9.3750  7.420000
# Viet Nam                                   126.5625        29.1875  3.087333
# Yemen                                      211.8125        39.3750  0.047333
# Zambia                                     354.3125        33.4375  2.239333
# Zimbabwe                                   462.3750        26.5625  4.482000
#
#                                     percentage expenditure  Hepatitis B  \
# Country
# Afghanistan                                      34.960110    64.562500
# Albania                                         193.259091    98.000000
# Algeria                                         236.185241    78.000000
# Angola                                          102.100268    70.222222
# Antigua and Barbuda                            1001.585226    98.266667
# ...                                                    ...          ...
# Venezuela (Bolivarian Republic of)                0.000000    66.250000
# Viet Nam                                          0.000000    87.538462
# Yemen                                             0.000000    55.687500
# Zambia                                           89.650407    69.818182
# Zimbabwe                                         20.364271    70.562500
#
#                                      Measles       BMI   under-five deaths   \
# Country
# Afghanistan                         2362.2500  15.51875            107.5625
# Albania                               53.3750  49.06875              0.9375
# Algeria                             1943.8750  48.74375             23.5000
# Angola                              3561.3125  18.01875            132.6250
# Antigua and Barbuda                    0.0000  38.42500              0.0000
# ...                                       ...       ...                 ...
# Venezuela (Bolivarian Republic of)   165.0000  54.48750             10.7500
# Viet Nam                            4232.9375  11.18750             36.5000
# Yemen                               2761.1875  33.48750             51.6250
# Zambia                              6563.8125  17.45000             52.3750
# Zimbabwe                             923.0000  25.13750             40.8125
#
#                                       Polio  Total expenditure  Diphtheria   \
# Country
# Afghanistan                         48.3750           8.252500      52.3125
# Albania                             98.1250           5.945625      98.0625
# Algeria                             91.7500           4.604000      91.8750
# Angola                              46.1250           3.919333      47.6875
# Antigua and Barbuda                 96.9375           4.791333      98.3125
# ...                                     ...                ...          ...
# Venezuela (Bolivarian Republic of)  74.6875           4.998667      68.5000
# Viet Nam                            94.9375           5.977333      91.7500
# Yemen                               67.1250           5.005333      72.6250
# Zambia                              64.3750           5.824000      74.2500
# Zimbabwe                            75.6250           6.158667      75.1875
#
#                                      HIV/AIDS          GDP    Population  \
# Country
# Afghanistan                           0.10000   340.015425  9.972260e+06
# Albania                               0.10000  2119.726679  6.969116e+05
# Algeria                               0.10000  2847.853392  2.164983e+07
# Angola                                2.36875  1975.143045  1.014710e+07
# Antigua and Barbuda                   0.12500  9759.305728  1.257006e+07
# ...                                       ...          ...           ...
# Venezuela (Bolivarian Republic of)    0.10000  7223.452050  1.257006e+07
# Viet Nam                              0.14375  7223.452050  1.257006e+07
# Yemen                                 0.10000  7223.452050  1.257006e+07
# Zambia                               11.93125   811.811841  6.260246e+06
# Zimbabwe                             23.26250   410.980194  8.021343e+06
#
#                                      thinness  1-19 years  \
# Country
# Afghanistan                                      16.58125
# Albania                                           1.61875
# Algeria                                           6.09375
# Angola                                            6.19375
# Antigua and Barbuda                               3.42500
# ...                                                   ...
# Venezuela (Bolivarian Republic of)                1.65000
# Viet Nam                                         14.92500
# Yemen                                            13.83125
# Zambia                                            6.88125
# Zimbabwe                                          7.01250
#
#                                      thinness 5-9 years  \
# Country
# Afghanistan                                    15.58125
# Albania                                         1.70000
# Algeria                                         5.97500
# Angola                                          6.66875
# Antigua and Barbuda                             3.37500
# ...                                                 ...
# Venezuela (Bolivarian Republic of)              1.56250
# Viet Nam                                       15.62500
# Yemen                                          13.75000
# Zambia                                          6.76250
# Zimbabwe                                        6.98750
#
#                                     Income composition of resources  \
# Country
# Afghanistan                                                0.415375
# Albania                                                    0.709875
# Algeria                                                    0.694875
# Angola                                                     0.458375
# Antigua and Barbuda                                        0.488625
# ...                                                             ...
# Venezuela (Bolivarian Republic of)                         0.726812
# Viet Nam                                                   0.627062
# Yemen                                                      0.475500
# Zambia                                                     0.498437
# Zimbabwe                                                   0.439125
#
#                                     Schooling  Developed  Developing
# Country
# Afghanistan                           8.21250        0.0         1.0
# Albania                              12.13750        0.0         1.0
# Algeria                              12.71250        0.0         1.0
# Angola                                8.04375        0.0         1.0
# Antigua and Barbuda                   8.84375        0.0         1.0
# ...                                       ...        ...         ...
# Venezuela (Bolivarian Republic of)   12.78750        0.0         1.0
# Viet Nam                             11.51250        0.0         1.0
# Yemen                                 8.50625        0.0         1.0
# Zambia                               11.21250        0.0         1.0
# Zimbabwe                              9.82500        0.0         1.0
#
# [193 rows x 20 columns]

# %%
life_labels.fillna(value = life_labels.mean(), inplace = True)

# %%
stats.describe(life_features[1:])
# Out:
# DescribeResult(nobs=192, minmax=(array([1.87500000e+01, 0.00000000e+00, 1.00000000e-02, 0.00000000e+00,
#        8.00000000e+00, 0.00000000e+00, 5.20000000e+00, 0.00000000e+00,
#        9.00000000e+00, 1.64666667e+00, 9.00000000e+00, 1.00000000e-01,
#        1.36183210e+02, 2.92000000e+02, 1.00000000e-01, 1.00000000e-01,
#        1.31687500e-01, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00]), array([5.50062500e+02, 1.36668750e+03, 1.34973333e+01, 9.80181038e+03,
#        9.90000000e+01, 6.58579375e+04, 8.73000000e+01, 1.81250000e+03,
#        9.90000000e+01, 1.72400000e+01, 9.90000000e+01, 3.29437500e+01,
#        5.73628746e+04, 4.21467691e+08, 2.71000000e+01, 2.79437500e+01,
#        9.31437500e-01, 2.00375000e+01, 1.00000000e+00, 1.00000000e+00])), mean=array([1.64253396e+02, 2.85745443e+01, 4.46296480e+00, 7.12321318e+02,
#        7.85909681e+01, 2.30174674e+03, 3.96797168e+01, 3.96419271e+01,
#        8.26078218e+01, 6.01668050e+00, 8.23842541e+01, 1.67047526e+00,
#        7.25930328e+03, 1.25835883e+07, 4.62089964e+00, 4.65416339e+00,
#        6.30617733e-01, 1.19132722e+01, 1.66666667e-01, 8.33333333e-01]), variance=array([8.75843142e+03, 1.28540496e+04, 1.48700520e+01, 2.10950227e+06,
#        3.38370018e+02, 6.25178778e+07, 3.01949462e+02, 2.36800172e+04,
#        2.74638648e+02, 4.83699092e+00, 2.92218598e+02, 1.89712358e+01,
#        9.65744006e+07, 1.09787565e+15, 1.57725109e+01, 1.65888768e+01,
#        3.03882176e-02, 1.03601660e+01, 1.39616056e-01, 1.39616056e-01]), skewness=array([ 1.19225145,  9.3630654 ,  0.5920435 ,  3.27460365, -1.36320782,
#         6.05254594,  0.09453142,  9.01254987, -1.3261097 ,  1.66458352,
#        -1.43066862,  4.23443451,  2.46889639, 10.16055662,  1.72955815,
#         1.8023565 , -0.48106083, -0.71599891,  1.78885438, -1.78885438]), kurtosis=array([  1.604733  , 101.90959278,  -0.86402143,  12.36028988,
#          2.20027664,  38.55513895,  -0.66005587,  94.30411285,
#          1.85630801,   6.59116886,   2.06805175,  20.55716829,
#          6.62435538, 119.83739182,   5.27091348,   5.62745981,
#         -0.34978933,   1.50234464,   1.2       ,   1.2       ]))

# %%
min_max_scaler = MinMaxScaler()
life_features = min_max_scaler.fit_transform(life_features)

# %%
life_features
# Out:
# array([[4.71121045e-01, 5.72552248e-02, 3.24378429e-04, ...,
#         4.09856519e-01, 0.00000000e+00, 1.00000000e+00],
#        [4.95235855e-02, 5.03041112e-04, 3.58762543e-01, ...,
#         6.05739239e-01, 0.00000000e+00, 1.00000000e+00],
#        [1.68333137e-01, 1.48625783e-02, 2.94103109e-02, ...,
#         6.34435434e-01, 0.00000000e+00, 1.00000000e+00],
#        ...,
#        [3.63369015e-01, 2.88105364e-02, 2.76802926e-03, ...,
#         4.24516532e-01, 0.00000000e+00, 1.00000000e+00],
#        [6.31572756e-01, 2.44660905e-02, 1.65290890e-01, ...,
#         5.59575795e-01, 0.00000000e+00, 1.00000000e+00],
#        [8.34960593e-01, 1.94356793e-02, 3.31570362e-01, ...,
#         4.90330630e-01, 0.00000000e+00, 1.00000000e+00]])

# %%
life_features_train, life_features_test, life_labels_train, life_labels_test = train_test_split(life_features, life_labels, train_size = 0.7, test_size =0.3)

# %% [markdown]
# CHECKING FOR ASSUMPTIONS OF LINEAR REGRESSION

# %% [markdown]
# 1. MULTICOLLINEARITY

# %%
plt.figure(figsize = (14, 10))
sns.heatmap(life_data.corr(), annot = True)

# %%
import statsmodels.api as sma
model0 = sma.OLS(life_labels, life_features)
results = model0.fit()
print(results.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Life expectancy    R-squared:                       0.928
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     117.6
# Date:                Mon, 02 May 2022   Prob (F-statistic):           2.52e-88
# Time:                        14:50:27   Log-Likelihood:                -442.13
# No. Observations:                 193   AIC:                             924.3
# Df Residuals:                     173   BIC:                             989.5
# Df Model:                          19
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           -27.6446      1.994    -13.865      0.000     -31.580     -23.709
# x2            71.2703     35.033      2.034      0.043       2.123     140.418
# x3             2.3082      0.968      2.384      0.018       0.397       4.219
# x4             2.9738      3.481      0.854      0.394      -3.897       9.845
# x5            -1.8981      1.739     -1.092      0.276      -5.330       1.533
# x6             0.9135      2.690      0.340      0.735      -4.396       6.223
# x7             3.1599      1.538      2.055      0.041       0.124       6.196
# x8           -83.9408     32.262     -2.602      0.010    -147.618     -20.264
# x9            -1.5244      3.426     -0.445      0.657      -8.286       5.238
# x10            2.4357      1.615      1.509      0.133      -0.751       5.622
# x11            8.8239      3.302      2.672      0.008       2.305      15.342
# x12           -4.7556      2.058     -2.311      0.022      -8.818      -0.693
# x13            0.5736      3.072      0.187      0.852      -5.490       6.637
# x14            9.0009      6.743      1.335      0.184      -4.309      22.311
# x15           -4.0545      7.614     -0.533      0.595     -19.083      10.974
# x16            5.4848      7.695      0.713      0.477      -9.702      20.672
# x17            5.7207      1.719      3.328      0.001       2.328       9.113
# x18            4.7300      2.235      2.116      0.036       0.319       9.141
# x19           62.8089      1.945     32.289      0.000      58.969      66.648
# x20           63.0307      1.767     35.677      0.000      59.544      66.518
# ==============================================================================
# Omnibus:                        3.612   Durbin-Watson:                   2.080
# Prob(Omnibus):                  0.164   Jarque-Bera (JB):                3.785
# Skew:                          -0.146   Prob(JB):                        0.151
# Kurtosis:                       3.621   Cond. No.                         521.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# 2. HOMOSCEDASTICITY

# %%
from statsmodels.compat import lzip
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
name = ['Lagrange multiplier statistic', 'p-value',
        'f-value', 'f p-value']
test = sms.het_breuschpagan(results.resid, results.model.exog)
lzip(name, test)
# Out:
# [('Lagrange multiplier statistic', 44.31111514793599),
#  ('p-value', 0.0008550825632833272),
#  ('f-value', 2.7134803293679584),
#  ('f p-value', 0.00032654295767255446)]

# %% [markdown]
# LINEAR REGRESSION

# %%
linear_model = LinearRegression()

# %%
linear_model.fit(life_features_train, life_labels_train)
# Out:
# LinearRegression()

# %%
print('Intercept:')
print(linear_model.intercept_)
# Out:
# Intercept:
# 61.25278047559356

# %%
print('Coefficients: \n', linear_model.coef_)
# Out:
# Coefficients:
#  [-25.03946943  50.79685648   1.52887352   3.49401679  -3.47893531
#   -1.46794993   3.5361368  -60.72242325  -1.34704546   4.04994994
#   10.03493815  -6.20794432   0.52937578   6.91521146  -4.89084335
#    7.67891448   6.91909918   4.15510931  -0.09555309   0.09555309]

# %%
print('R_square score on the training: %.2f' % linear_model.score(life_features_train, life_labels_train))
# Out:
# R_square score on the training: 0.93

# %%
linear_model_predict = linear_model.predict(life_features_test)

# %%
print("Mean squared error: %.2f" % mean_squared_error(life_labels_test, linear_model_predict))
print("Mean absolute error: %.2f" % mean_absolute_error(life_labels_test, linear_model_predict))
print("Root mean squared error: %.2f" %np.sqrt(metrics.mean_squared_error(life_labels_test, linear_model_predict)))
# Out:
# Mean squared error: 7.17
# Mean absolute error: 2.05
# Root mean squared error: 2.68

# %%
print('R_square score: %.2f' % r2_score(life_labels_test, linear_model_predict))
# Out:
# R_square score: 0.91

# %% [markdown]
# FEATURE SELECTION WITH OLS MODEL

# %%
import statsmodels.api as sma
model = sma.OLS(life_labels, life_features)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Life expectancy    R-squared:                       0.928
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     117.6
# Date:                Mon, 02 May 2022   Prob (F-statistic):           2.52e-88
# Time:                        14:54:37   Log-Likelihood:                -442.13
# No. Observations:                 193   AIC:                             924.3
# Df Residuals:                     173   BIC:                             989.5
# Df Model:                          19
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           -27.6446      1.994    -13.865      0.000     -31.580     -23.709
# x2            71.2703     35.033      2.034      0.043       2.123     140.418
# x3             2.3082      0.968      2.384      0.018       0.397       4.219
# x4             2.9738      3.481      0.854      0.394      -3.897       9.845
# x5            -1.8981      1.739     -1.092      0.276      -5.330       1.533
# x6             0.9135      2.690      0.340      0.735      -4.396       6.223
# x7             3.1599      1.538      2.055      0.041       0.124       6.196
# x8           -83.9408     32.262     -2.602      0.010    -147.618     -20.264
# x9            -1.5244      3.426     -0.445      0.657      -8.286       5.238
# x10            2.4357      1.615      1.509      0.133      -0.751       5.622
# x11            8.8239      3.302      2.672      0.008       2.305      15.342
# x12           -4.7556      2.058     -2.311      0.022      -8.818      -0.693
# x13            0.5736      3.072      0.187      0.852      -5.490       6.637
# x14            9.0009      6.743      1.335      0.184      -4.309      22.311
# x15           -4.0545      7.614     -0.533      0.595     -19.083      10.974
# x16            5.4848      7.695      0.713      0.477      -9.702      20.672
# x17            5.7207      1.719      3.328      0.001       2.328       9.113
# x18            4.7300      2.235      2.116      0.036       0.319       9.141
# x19           62.8089      1.945     32.289      0.000      58.969      66.648
# x20           63.0307      1.767     35.677      0.000      59.544      66.518
# ==============================================================================
# Omnibus:                        3.612   Durbin-Watson:                   2.080
# Prob(Omnibus):                  0.164   Jarque-Bera (JB):                3.785
# Skew:                          -0.146   Prob(JB):                        0.151
# Kurtosis:                       3.621   Cond. No.                         521.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X.columns
# Out:
# Index(['Adult Mortality', 'infant deaths', 'Alcohol', 'percentage expenditure',
#        'Hepatitis B', 'Measles ', ' BMI ', 'under-five deaths ', 'Polio',
#        'Total expenditure', 'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling', 'Developed',
#        'Developing'],
#       dtype='object')

# %%
#remove the following : GDP(P=0.852)
new=X.drop(['GDP','Measles ','Polio',' thinness  1-19 years',' thinness 5-9 years'] ,axis=1)

# %%
new.fillna(value = new.mean(), inplace = True)
new
# Out:
#                                     Adult Mortality  infant deaths   Alcohol  \
# Country
# Afghanistan                                269.0625        78.2500  0.014375
# Albania                                     45.0625         0.6875  4.848750
# Algeria                                    108.1875        20.3125  0.406667
# Angola                                     328.5625        83.7500  5.740667
# Antigua and Barbuda                        127.5000         0.0000  7.949333
# ...                                             ...            ...       ...
# Venezuela (Bolivarian Republic of)         163.0000         9.3750  7.420000
# Viet Nam                                   126.5625        29.1875  3.087333
# Yemen                                      211.8125        39.3750  0.047333
# Zambia                                     354.3125        33.4375  2.239333
# Zimbabwe                                   462.3750        26.5625  4.482000
#
#                                     percentage expenditure  Hepatitis B  \
# Country
# Afghanistan                                      34.960110    64.562500
# Albania                                         193.259091    98.000000
# Algeria                                         236.185241    78.000000
# Angola                                          102.100268    70.222222
# Antigua and Barbuda                            1001.585226    98.266667
# ...                                                    ...          ...
# Venezuela (Bolivarian Republic of)                0.000000    66.250000
# Viet Nam                                          0.000000    87.538462
# Yemen                                             0.000000    55.687500
# Zambia                                           89.650407    69.818182
# Zimbabwe                                         20.364271    70.562500
#
#                                         BMI   under-five deaths   \
# Country
# Afghanistan                         15.51875            107.5625
# Albania                             49.06875              0.9375
# Algeria                             48.74375             23.5000
# Angola                              18.01875            132.6250
# Antigua and Barbuda                 38.42500              0.0000
# ...                                      ...                 ...
# Venezuela (Bolivarian Republic of)  54.48750             10.7500
# Viet Nam                            11.18750             36.5000
# Yemen                               33.48750             51.6250
# Zambia                              17.45000             52.3750
# Zimbabwe                            25.13750             40.8125
#
#                                     Total expenditure  Diphtheria    HIV/AIDS  \
# Country
# Afghanistan                                  8.252500      52.3125    0.10000
# Albania                                      5.945625      98.0625    0.10000
# Algeria                                      4.604000      91.8750    0.10000
# Angola                                       3.919333      47.6875    2.36875
# Antigua and Barbuda                          4.791333      98.3125    0.12500
# ...                                               ...          ...        ...
# Venezuela (Bolivarian Republic of)           4.998667      68.5000    0.10000
# Viet Nam                                     5.977333      91.7500    0.14375
# Yemen                                        5.005333      72.6250    0.10000
# Zambia                                       5.824000      74.2500   11.93125
# Zimbabwe                                     6.158667      75.1875   23.26250
#
#                                       Population  \
# Country
# Afghanistan                         9.972260e+06
# Albania                             6.969116e+05
# Algeria                             2.164983e+07
# Angola                              1.014710e+07
# Antigua and Barbuda                 1.257006e+07
# ...                                          ...
# Venezuela (Bolivarian Republic of)  1.257006e+07
# Viet Nam                            1.257006e+07
# Yemen                               1.257006e+07
# Zambia                              6.260246e+06
# Zimbabwe                            8.021343e+06
#
#                                     Income composition of resources  \
# Country
# Afghanistan                                                0.415375
# Albania                                                    0.709875
# Algeria                                                    0.694875
# Angola                                                     0.458375
# Antigua and Barbuda                                        0.488625
# ...                                                             ...
# Venezuela (Bolivarian Republic of)                         0.726812
# Viet Nam                                                   0.627062
# Yemen                                                      0.475500
# Zambia                                                     0.498437
# Zimbabwe                                                   0.439125
#
#                                     Schooling  Developed  Developing
# Country
# Afghanistan                           8.21250        0.0         1.0
# Albania                              12.13750        0.0         1.0
# Algeria                              12.71250        0.0         1.0
# Angola                                8.04375        0.0         1.0
# Antigua and Barbuda                   8.84375        0.0         1.0
# ...                                       ...        ...         ...
# Venezuela (Bolivarian Republic of)   12.78750        0.0         1.0
# Viet Nam                             11.51250        0.0         1.0
# Yemen                                 8.50625        0.0         1.0
# Zambia                               11.21250        0.0         1.0
# Zimbabwe                              9.82500        0.0         1.0
#
# [193 rows x 15 columns]

# %% [markdown]
# LINEAR REGRESSION WITH SELECTED FEATURES ONLY

# %%
new_train, new_test, life_labels_train, life_labels_test = train_test_split(new, life_labels, train_size = 0.7, test_size = 0.3)
linear_model = LinearRegression()

# %%
linear_model.fit(new_train, life_labels_train)
# Out:
# LinearRegression()

# %%
print('R_square score on the training: %.2f' % linear_model.score(new_train, life_labels_train))
# Out:
# R_square score on the training: 0.92

# %%
linear_model_predict = linear_model.predict(new_test)

# %%
print("Mean squared error: %.2f" % mean_squared_error(life_labels_test, linear_model_predict))
print("Mean absolute error: %.2f" % mean_absolute_error(life_labels_test, linear_model_predict))
print("Root mean squared error: %.2f" %np.sqrt(metrics.mean_squared_error(life_labels_test, linear_model_predict)))
# Out:
# Mean squared error: 5.59
# Mean absolute error: 1.92
# Root mean squared error: 2.37

# %%
print('R_square score: %.2f' % r2_score(life_labels_test, linear_model_predict))
# Out:
# R_square score: 0.93
